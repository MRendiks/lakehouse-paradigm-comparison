# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Notebook ini digunakan untuk eksplorasi data awal.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_parquet('data/sample.parquet')
# df.head()
